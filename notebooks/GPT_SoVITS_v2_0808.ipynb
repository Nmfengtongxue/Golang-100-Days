# %% [markdown]
# <a href="https://colab.research.google.com/github/Nmfengtongxue/Golang-100-Days/blob/master/notebooks/GPT_SoVITS_v2_0808.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title 一键运行第二代 GPT-SoVITS
# !git clone https://huggingface.co/spaces/kevinwang676/GPT-SoVITS-v2.git
# %cd GPT-SoVITS-v2
# !pip install --disable-pip-version-check -r requirements.txt
# !sudo apt install ffmpeg
# !sudo apt install libsox-dev
import nltk
nltk.download("all")
# !python webui.py
# Out:
# Cloning into 'GPT-SoVITS-v2'...
# remote: Enumerating objects: 382, done.
# remote: Counting objects: 100% (378/378), done.
# remote: Compressing objects: 100% (361/361), done.
# remote: Total 382 (delta 79), reused 0 (delta 0), pack-reused 4 (from 1)
# Receiving objects: 100% (382/382), 6.24 MiB | 4.61 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# Filtering content: 100% (18/18), 3.90 GiB | 59.75 MiB/s, done.
# /content/GPT-SoVITS-v2/GPT-SoVITS-v2/GPT-SoVITS-v2/GPT-SoVITS-v2
# Ignoring onnxruntime: markers 'sys_platform == "darwin"' don't match your environment
# Ignoring opencc: markers 'sys_platform != "linux"' don't match your environment
# ...
#   Using cached numpy-1.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# ...
#   Using cached librosa-0.9.2-py3-none-any.whl.metadata (8.2 kB)
# ...
#   Using cached numba-0.56.4.tar.gz (2.4 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
# ...

# %%
# !sudo apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.
